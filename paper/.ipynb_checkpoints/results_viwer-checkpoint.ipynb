# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
from glob import glob

# %%
def open_cfg(file):
    with open(file, 'rt') as f:
        data = json.loads(f.read())

    for key in list(data.keys()):
        if type(data[key]) == list:
            data[key] = tuple(data[key])
    return data

def dicts_equal(dict1, dict2):
    keys1 = tuple(sorted(list(dict1.keys())))
    keys2 = tuple(sorted(list(dict2.keys())))
    if keys1 != keys2:
        return False
    for key in keys1:
        if dict1[key] != dict2[key]:
            return False
    return True

# %%
MODELS = ['ISIBrno_model', 'CNN_model', 'RNN_model', 'ECGConvEncoder', 'ECGConvEncoder_v2', 'ECGConvEncoder_v3']
TRAIN_DATASETS = [['ptb_xl'], ['ptb_xl', 'ningbo'], ['ptb_xl', 'ningbo', 'georgia']]
EXP2_DATASETS = ['sph', 'code15']

# %%
results = sorted(glob('results/*.csv'))
print(len(results))
results = {log: pd.read_csv(log) for log in results}
print(len(results))
results = {key.removeprefix('results/').removesuffix('.csv'): val for key, val in results.items()}
results = {key: {'log': val, 'cfg': open_cfg(f'results/{key}.cfg')} for key, val in results.items() if os.path.isfile(f'results/{key}.cfg')}
print(len(results))
results = {key: val for key, val in results.items() if val['cfg']['ecg_encoder_model'] in MODELS}
print(len(results))
# Out:
# 12
# 12
# 11
# 11

# %%
for model in MODELS:
    print()
    print(model)
    model_results = {key: val for key, val in results.items() if val['cfg']['ecg_encoder_model'] == model}
    if model == 'ISIBrno_model':
        model_results = {key: val for key, val in model_results.items() if val['cfg']['device'] == 'cuda:0'}
    if model == 'ECGConvEncoder':
        model_results = {key: val for key, val in model_results.items() if val['cfg']['device'] == 'cuda:3'}
    print(len(model_results))
    if len(model_results) > 0:

        for datasets in TRAIN_DATASETS:
            print()
            #print(datasets)
            ds_results = {key: val for key, val in model_results.items() if val['cfg']['train_datasets'] == tuple(datasets)}
            #print(len(ds_results))
            if len(ds_results) > 0:
    
                for train_ds in datasets:
                    vals = [res['cfg']['test_metrics'][train_ds]['mean_rocaucs'] for res in ds_results.values()]
                    print(f'{train_ds} test metrics: {np.mean(vals):.3f}+/-{np.std(vals):.3f}')
        
                
                for train_ds in datasets:
                    vals = [res['cfg']['zero_shot_test_metrics'][train_ds]['mean_rocaucs'] for res in ds_results.values()]
                    print(f'{train_ds} zero-shot metrics: {np.mean(vals):.3f}+/-{np.std(vals):.3f}') 
        
        
                for exp2_ds in EXP2_DATASETS:
                    vals = [res['cfg']['exp2_metrics_trained'][exp2_ds]['mean_rocaucs'] for res in ds_results.values()]
                    print(f'{exp2_ds} trained metrics: {np.mean(vals):.3f}+/-{np.std(vals):.3f}')
        
        
                for exp2_ds in EXP2_DATASETS:
                    vals = [res['cfg']['exp2_metrics_untrained'][exp2_ds]['mean_rocaucs'] for res in ds_results.values()]
                    print(f'{exp2_ds} zero-shot metrics: {np.mean(vals):.3f}+/-{np.std(vals):.3f}')
                #plt.figure(figsize=(30, 5))
                #for result in ds_results.values():
                #    plt.plot(result['log']['valid_mean_rocaucs'])
                #plt.grid()
                #plt.show()
# Out:
# ISIBrno_model
# 11
#
# ptb_xl test metrics: 0.747+/-0.059
# ptb_xl zero-shot metrics: 0.574+/-0.037
# sph trained metrics: 0.713+/-0.028
# code15 trained metrics: 0.692+/-0.073
# sph zero-shot metrics: 0.656+/-0.032
# code15 zero-shot metrics: 0.597+/-0.114
#
# ptb_xl test metrics: 0.769+/-0.023
# ningbo test metrics: 0.774+/-0.027
# ptb_xl zero-shot metrics: 0.638+/-0.048
# ningbo zero-shot metrics: 0.546+/-0.039
# sph trained metrics: 0.824+/-0.043
# code15 trained metrics: 0.851+/-0.051
# sph zero-shot metrics: 0.710+/-0.034
# code15 zero-shot metrics: 0.727+/-0.098
#
# ptb_xl test metrics: 0.739+/-0.056
# ningbo test metrics: 0.705+/-0.100
# georgia test metrics: 0.693+/-0.060
# ptb_xl zero-shot metrics: 0.582+/-0.021
# ningbo zero-shot metrics: 0.534+/-0.025
# georgia zero-shot metrics: 0.545+/-0.035
# sph trained metrics: 0.785+/-0.049
# code15 trained metrics: 0.886+/-0.017
# sph zero-shot metrics: 0.647+/-0.086
# code15 zero-shot metrics: 0.485+/-0.055
#
# CNN_model
# 0
#
# RNN_model
# 0
#
# ECGConvEncoder
# 0
#
# ECGConvEncoder_v2
# 0
#
# ECGConvEncoder_v3
# 0

# %%
for key, val in results.items():
    print('*'*80)
    print('Train classes:')
    print(len(val['cfg']['train_classes']))
    print(val['cfg']['train_classes'])
    print()
    print('Valid classes:')
    print(len(val['cfg']['valid_classes']))
    print(val['cfg']['valid_classes'])
    print()
    print('Test classes:')
    print(len(val['cfg']['test_classes']))
    print(val['cfg']['test_classes'])
    print()
    print('Zero-shot classes:')
    print(len(val['cfg']['zero_shot_classes']))
    print(val['cfg']['zero_shot_classes'])
    print()


    print('Exp2 trained classes:')
    print(len(val['cfg']['exp2_trained_classes']))
    print(val['cfg']['exp2_trained_classes'])
    print()    

    print('Exp2 untrained classes:')
    print(len(val['cfg']['exp2_untrained_classes']))
    print(val['cfg']['exp2_untrained_classes'])
    print()
# Out:
# ********************************************************************************
# Train classes:
# 26
# ('1st degree av block', 'abnormal QRS', 'anterior myocardial infarction', 'atrial flutter', 'bundle branch block', 'complete right bundle branch block', 'early repolarization', 'incomplete right bundle branch block', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial infarction', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'pacing rhythm', 'premature ventricular contractions', 'prolonged pr interval', 'prolonged qt interval', 'qwave abnormal', 'right axis deviation', 'st interval abnormal', 't wave inversion')
#
# Valid classes:
# 15
# ('1st degree av block', 'abnormal QRS', 'atrial flutter', 'complete right bundle branch block', 'incomplete right bundle branch block', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial infarction', 'nonspecific intraventricular conduction disorder', 'normal ecg', 'pacing rhythm', 'qwave abnormal', 't wave inversion')
#
# Test classes:
# 15
# ('1st degree av block', 'abnormal QRS', 'atrial flutter', 'complete right bundle branch block', 'incomplete right bundle branch block', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial infarction', 'nonspecific intraventricular conduction disorder', 'normal ecg', 'pacing rhythm', 'qwave abnormal', 't wave inversion')
#
# Zero-shot classes:
# 10
# ('atrial fibrillation', 'myocardial ischemia', 'premature atrial contraction', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 'st depression', 't wave abnormal', 'ventricular ectopics')
#
# Exp2 trained classes:
# 2
# {'sph': ['prolonged pr interval', 'left ventricular hypertrophy', 'normal ecg'], 'code15': ['normal ecg', 'left bundle branch block']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'sinus bradycardia', 'atrial fibrillation', 'sinus tachycardia', 'sinus arrhythmia', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block', 'atrial fibrillation', 'sinus bradycardia', 'sinus tachycardia']}
#
# ********************************************************************************
# Train classes:
# 22
# ('1st degree av block', 'anterior myocardial infarction', 'atrial fibrillation', 'complete right bundle branch block', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'myocardial infarction', 'myocardial ischemia', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'prolonged pr interval', 'qwave abnormal', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 'st depression')
#
# Valid classes:
# 6
# ('atrial fibrillation', 'left anterior fascicular block', 'left axis deviation', 'myocardial infarction', 'myocardial ischemia', 'normal ecg')
#
# Test classes:
# 6
# ('atrial fibrillation', 'left anterior fascicular block', 'left axis deviation', 'myocardial infarction', 'myocardial ischemia', 'normal ecg')
#
# Zero-shot classes:
# 5
# ('abnormal QRS', 'incomplete right bundle branch block', 'left ventricular hypertrophy', 't wave abnormal', 'ventricular ectopics')
#
# Exp2 trained classes:
# 2
# {'sph': ['normal ecg', 'atrial fibrillation', 'prolonged pr interval', 'sinus bradycardia', 'sinus tachycardia', 'sinus arrhythmia'], 'code15': ['left bundle branch block', 'atrial fibrillation', 'sinus bradycardia', 'sinus tachycardia', 'normal ecg']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'left ventricular hypertrophy', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block']}
#
# ********************************************************************************
# Train classes:
# 27
# ('1st degree av block', 'abnormal QRS', 'anterior myocardial infarction', 'atrial fibrillation', 'atrial flutter', 'bundle branch block', 'complete right bundle branch block', 'early repolarization', 'inferior ischaemia', 'left bundle branch block', 'low qrs voltages', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'pacing rhythm', 'premature atrial contraction', 'premature ventricular contractions', 'prolonged pr interval', 'prolonged qt interval', 'right axis deviation', 'right bundle branch block', 's t changes', 'sinus arrhythmia', 'st depression', 't wave abnormal', 't wave inversion', 'ventricular premature beats')
#
# Valid classes:
# 18
# ('1st degree av block', 'abnormal QRS', 'atrial fibrillation', 'atrial flutter', 'complete right bundle branch block', 'low qrs voltages', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'pacing rhythm', 'premature atrial contraction', 'prolonged qt interval', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'st depression', 't wave abnormal', 't wave inversion')
#
# Test classes:
# 18
# ('1st degree av block', 'abnormal QRS', 'atrial fibrillation', 'atrial flutter', 'complete right bundle branch block', 'low qrs voltages', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'pacing rhythm', 'premature atrial contraction', 'prolonged qt interval', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'st depression', 't wave abnormal', 't wave inversion')
#
# Zero-shot classes:
# 13
# ('incomplete right bundle branch block', 'lateral ischaemia', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left ventricular hypertrophy', 'myocardial infarction', 'myocardial ischemia', 'qwave abnormal', 'sinus bradycardia', 'sinus tachycardia', 'st interval abnormal', 'ventricular ectopics')
#
# Exp2 trained classes:
# 2
# {'sph': ['normal ecg', 'prolonged pr interval', 'atrial fibrillation', 'sinus arrhythmia'], 'code15': ['normal ecg', 'right bundle branch block', 'atrial fibrillation', 'left bundle branch block']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'left ventricular hypertrophy', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'sinus bradycardia', 'sinus tachycardia', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'sinus bradycardia', 'sinus tachycardia']}
#
# ********************************************************************************
# Train classes:
# 21
# ('1st degree av block', 'abnormal QRS', 'anterior myocardial infarction', 'atrial fibrillation', 'complete right bundle branch block', 'incomplete right bundle branch block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'left ventricular hypertrophy', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'qwave abnormal', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 't wave abnormal')
#
# Valid classes:
# 7
# ('abnormal QRS', 'atrial fibrillation', 'incomplete right bundle branch block', 'left axis deviation', 'left ventricular hypertrophy', 'normal ecg', 't wave abnormal')
#
# Test classes:
# 7
# ('abnormal QRS', 'atrial fibrillation', 'incomplete right bundle branch block', 'left axis deviation', 'left ventricular hypertrophy', 'normal ecg', 't wave abnormal')
#
# Zero-shot classes:
# 5
# ('left anterior fascicular block', 'myocardial infarction', 'myocardial ischemia', 'st depression', 'ventricular ectopics')
#
# Exp2 trained classes:
# 2
# {'sph': ['left ventricular hypertrophy', 'atrial fibrillation', 'normal ecg', 'sinus bradycardia', 'sinus tachycardia', 'sinus arrhythmia'], 'code15': ['left bundle branch block', 'atrial fibrillation', 'sinus bradycardia', 'sinus tachycardia', 'normal ecg']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'prolonged pr interval', 'st deviation with t-wave change', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block']}
#
# ********************************************************************************
# Train classes:
# 27
# ('1st degree av block', 'anterior myocardial infarction', 'atrial flutter', 'bundle branch block', 'complete right bundle branch block', 'early repolarization', 'incomplete right bundle branch block', 'inferior ischaemia', 'lateral ischaemia', 'left anterior fascicular block', 'left bundle branch block', 'left ventricular hypertrophy', 'myocardial ischemia', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'premature ventricular contractions', 'prolonged pr interval', 'qwave abnormal', 'right bundle branch block', 'sinus arrhythmia', 'sinus bradycardia', 'st depression', 'st interval abnormal', 't wave inversion', 'ventricular ectopics', 'ventricular premature beats')
#
# Valid classes:
# 19
# ('1st degree av block', 'atrial flutter', 'complete right bundle branch block', 'incomplete right bundle branch block', 'lateral ischaemia', 'left anterior fascicular block', 'left ventricular hypertrophy', 'myocardial ischemia', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'premature ventricular contractions', 'qwave abnormal', 'sinus arrhythmia', 'sinus bradycardia', 'st depression', 'st interval abnormal', 't wave inversion', 'ventricular ectopics')
#
# Test classes:
# 19
# ('1st degree av block', 'atrial flutter', 'complete right bundle branch block', 'incomplete right bundle branch block', 'lateral ischaemia', 'left anterior fascicular block', 'left ventricular hypertrophy', 'myocardial ischemia', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'premature ventricular contractions', 'qwave abnormal', 'sinus arrhythmia', 'sinus bradycardia', 'st depression', 'st interval abnormal', 't wave inversion', 'ventricular ectopics')
#
# Zero-shot classes:
# 13
# ('abnormal QRS', 'atrial fibrillation', 'left atrial enlargement', 'left axis deviation', 'low qrs voltages', 'myocardial infarction', 'nonspecific intraventricular conduction disorder', 'pacing rhythm', 'prolonged qt interval', 'right axis deviation', 's t changes', 'sinus tachycardia', 't wave abnormal')
#
# Exp2 trained classes:
# 2
# {'sph': ['sinus arrhythmia', 'left ventricular hypertrophy', 'prolonged pr interval', 'sinus bradycardia', 'normal ecg'], 'code15': ['normal ecg', 'right bundle branch block', 'left bundle branch block', 'sinus bradycardia']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'atrial fibrillation', 'sinus tachycardia', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'sinus tachycardia', 'atrial fibrillation']}
#
# ********************************************************************************
# Train classes:
# 22
# ('1st degree av block', 'anterior myocardial infarction', 'atrial fibrillation', 'complete right bundle branch block', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'left ventricular hypertrophy', 'myocardial infarction', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'prolonged pr interval', 'qwave abnormal', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 't wave abnormal')
#
# Valid classes:
# 7
# ('atrial fibrillation', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'myocardial infarction', 'normal ecg', 't wave abnormal')
#
# Test classes:
# 7
# ('atrial fibrillation', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'myocardial infarction', 'normal ecg', 't wave abnormal')
#
# Zero-shot classes:
# 5
# ('abnormal QRS', 'incomplete right bundle branch block', 'myocardial ischemia', 'st depression', 'ventricular ectopics')
#
# Exp2 trained classes:
# 2
# {'sph': ['normal ecg', 'left ventricular hypertrophy', 'atrial fibrillation', 'prolonged pr interval', 'sinus bradycardia', 'sinus tachycardia', 'sinus arrhythmia'], 'code15': ['left bundle branch block', 'atrial fibrillation', 'sinus bradycardia', 'sinus tachycardia', 'normal ecg']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block']}
#
# ********************************************************************************
# Train classes:
# 26
# ('anterior myocardial infarction', 'atrial fibrillation', 'atrial flutter', 'bundle branch block', 'complete right bundle branch block', 'early repolarization', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'low qrs voltages', 'myocardial ischemia', 'nonspecific st t abnormality', 'normal ecg', 'pacing rhythm', 'premature ventricular contractions', 'prolonged pr interval', 'prolonged qt interval', 'qwave abnormal', 'right axis deviation', 'sinus arrhythmia', 'sinus tachycardia', 'st depression', 'st interval abnormal', 't wave inversion', 'ventricular ectopics')
#
# Valid classes:
# 16
# ('atrial fibrillation', 'atrial flutter', 'complete right bundle branch block', 'left anterior fascicular block', 'left axis deviation', 'low qrs voltages', 'myocardial ischemia', 'normal ecg', 'pacing rhythm', 'qwave abnormal', 'right axis deviation', 'sinus arrhythmia', 'sinus tachycardia', 'st depression', 't wave inversion', 'ventricular ectopics')
#
# Test classes:
# 16
# ('atrial fibrillation', 'atrial flutter', 'complete right bundle branch block', 'left anterior fascicular block', 'left axis deviation', 'low qrs voltages', 'myocardial ischemia', 'normal ecg', 'pacing rhythm', 'qwave abnormal', 'right axis deviation', 'sinus arrhythmia', 'sinus tachycardia', 'st depression', 't wave inversion', 'ventricular ectopics')
#
# Zero-shot classes:
# 10
# ('1st degree av block', 'abnormal QRS', 'incomplete right bundle branch block', 'left ventricular hypertrophy', 'myocardial infarction', 'nonspecific intraventricular conduction disorder', 'premature atrial contraction', 's t changes', 'sinus bradycardia', 't wave abnormal')
#
# Exp2 trained classes:
# 2
# {'sph': ['sinus arrhythmia', 'atrial fibrillation', 'prolonged pr interval', 'sinus tachycardia', 'normal ecg'], 'code15': ['normal ecg', 'sinus tachycardia', 'left bundle branch block', 'atrial fibrillation']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'left ventricular hypertrophy', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'sinus bradycardia', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block', 'sinus bradycardia']}
#
# ********************************************************************************
# Train classes:
# 20
# ('1st degree av block', 'abnormal QRS', 'anterior myocardial infarction', 'atrial fibrillation', 'complete right bundle branch block', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'left ventricular hypertrophy', 'nonspecific intraventricular conduction disorder', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'qwave abnormal', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 'ventricular ectopics')
#
# Valid classes:
# 7
# ('abnormal QRS', 'atrial fibrillation', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'normal ecg', 'ventricular ectopics')
#
# Test classes:
# 7
# ('abnormal QRS', 'atrial fibrillation', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'normal ecg', 'ventricular ectopics')
#
# Zero-shot classes:
# 5
# ('incomplete right bundle branch block', 'myocardial infarction', 'myocardial ischemia', 'st depression', 't wave abnormal')
#
# Exp2 trained classes:
# 2
# {'sph': ['left ventricular hypertrophy', 'atrial fibrillation', 'normal ecg', 'sinus bradycardia', 'sinus tachycardia', 'sinus arrhythmia'], 'code15': ['left bundle branch block', 'atrial fibrillation', 'sinus bradycardia', 'sinus tachycardia', 'normal ecg']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'prolonged pr interval', 'st deviation with t-wave change', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block']}
#
# ********************************************************************************
# Train classes:
# 27
# ('abnormal QRS', 'anterior myocardial infarction', 'atrial fibrillation', 'atrial flutter', 'bundle branch block', 'early repolarization', 'inferior ischaemia', 'lateral ischaemia', 'left anterior fascicular block', 'left bundle branch block', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial ischemia', 'nonspecific intraventricular conduction disorder', 'normal ecg', 'premature ventricular contractions', 'prolonged pr interval', 'prolonged qt interval', 'qwave abnormal', 'right axis deviation', 'right bundle branch block', 's t changes', 'sinus tachycardia', 'st depression', 't wave abnormal', 'ventricular ectopics', 'ventricular premature beats')
#
# Valid classes:
# 18
# ('abnormal QRS', 'atrial fibrillation', 'atrial flutter', 'lateral ischaemia', 'left anterior fascicular block', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial ischemia', 'nonspecific intraventricular conduction disorder', 'normal ecg', 'premature ventricular contractions', 'prolonged qt interval', 'qwave abnormal', 's t changes', 'sinus tachycardia', 'st depression', 't wave abnormal', 'ventricular ectopics')
#
# Test classes:
# 18
# ('abnormal QRS', 'atrial fibrillation', 'atrial flutter', 'lateral ischaemia', 'left anterior fascicular block', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial ischemia', 'nonspecific intraventricular conduction disorder', 'normal ecg', 'premature ventricular contractions', 'prolonged qt interval', 'qwave abnormal', 's t changes', 'sinus tachycardia', 'st depression', 't wave abnormal', 'ventricular ectopics')
#
# Zero-shot classes:
# 13
# ('1st degree av block', 'complete right bundle branch block', 'incomplete right bundle branch block', 'left atrial enlargement', 'left axis deviation', 'myocardial infarction', 'nonspecific st t abnormality', 'pacing rhythm', 'premature atrial contraction', 'sinus arrhythmia', 'sinus bradycardia', 'st interval abnormal', 't wave inversion')
#
# Exp2 trained classes:
# 2
# {'sph': ['left ventricular hypertrophy', 'atrial fibrillation', 'prolonged pr interval', 'sinus tachycardia', 'normal ecg'], 'code15': ['right bundle branch block', 'left bundle branch block', 'atrial fibrillation', 'sinus tachycardia', 'normal ecg']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'sinus bradycardia', 'sinus arrhythmia', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'sinus bradycardia']}
#
# ********************************************************************************
# Train classes:
# 26
# ('1st degree av block', 'anterior myocardial infarction', 'atrial fibrillation', 'atrial flutter', 'bundle branch block', 'complete right bundle branch block', 'early repolarization', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'low qrs voltages', 'myocardial infarction', 'nonspecific st t abnormality', 'normal ecg', 'premature ventricular contractions', 'prolonged pr interval', 'prolonged qt interval', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 'st depression', 'st interval abnormal', 't wave abnormal', 't wave inversion')
#
# Valid classes:
# 16
# ('1st degree av block', 'atrial fibrillation', 'atrial flutter', 'complete right bundle branch block', 'left axis deviation', 'myocardial infarction', 'normal ecg', 'premature ventricular contractions', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 'st depression', 't wave abnormal', 't wave inversion')
#
# Test classes:
# 16
# ('1st degree av block', 'atrial fibrillation', 'atrial flutter', 'complete right bundle branch block', 'left axis deviation', 'myocardial infarction', 'normal ecg', 'premature ventricular contractions', 'right axis deviation', 's t changes', 'sinus arrhythmia', 'sinus bradycardia', 'sinus tachycardia', 'st depression', 't wave abnormal', 't wave inversion')
#
# Zero-shot classes:
# 10
# ('abnormal QRS', 'incomplete right bundle branch block', 'left anterior fascicular block', 'left ventricular hypertrophy', 'myocardial ischemia', 'nonspecific intraventricular conduction disorder', 'pacing rhythm', 'premature atrial contraction', 'qwave abnormal', 'ventricular ectopics')
#
# Exp2 trained classes:
# 2
# {'sph': ['normal ecg', 'atrial fibrillation', 'prolonged pr interval', 'sinus bradycardia', 'sinus tachycardia', 'sinus arrhythmia'], 'code15': ['left bundle branch block', 'atrial fibrillation', 'sinus bradycardia', 'sinus tachycardia', 'normal ecg']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'left ventricular hypertrophy', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block']}
#
# ********************************************************************************
# Train classes:
# 26
# ('1st degree av block', 'anterior myocardial infarction', 'atrial flutter', 'bundle branch block', 'early repolarization', 'left anterior fascicular block', 'left atrial enlargement', 'left axis deviation', 'left bundle branch block', 'left ventricular hypertrophy', 'low qrs voltages', 'myocardial infarction', 'myocardial ischemia', 'nonspecific st t abnormality', 'normal ecg', 'premature atrial contraction', 'prolonged pr interval', 'prolonged qt interval', 'qwave abnormal', 'right axis deviation', 'sinus arrhythmia', 'sinus tachycardia', 'st depression', 'st interval abnormal', 't wave inversion', 'ventricular ectopics')
#
# Valid classes:
# 16
# ('1st degree av block', 'atrial flutter', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'myocardial infarction', 'myocardial ischemia', 'normal ecg', 'premature atrial contraction', 'qwave abnormal', 'right axis deviation', 'sinus arrhythmia', 'sinus tachycardia', 'st depression', 't wave inversion', 'ventricular ectopics')
#
# Test classes:
# 16
# ('1st degree av block', 'atrial flutter', 'left anterior fascicular block', 'left axis deviation', 'left ventricular hypertrophy', 'myocardial infarction', 'myocardial ischemia', 'normal ecg', 'premature atrial contraction', 'qwave abnormal', 'right axis deviation', 'sinus arrhythmia', 'sinus tachycardia', 'st depression', 't wave inversion', 'ventricular ectopics')
#
# Zero-shot classes:
# 10
# ('abnormal QRS', 'atrial fibrillation', 'complete right bundle branch block', 'incomplete right bundle branch block', 'nonspecific intraventricular conduction disorder', 'pacing rhythm', 'premature ventricular contractions', 's t changes', 'sinus bradycardia', 't wave abnormal')
#
# Exp2 trained classes:
# 2
# {'sph': ['sinus arrhythmia', 'left ventricular hypertrophy', 'prolonged pr interval', 'sinus tachycardia', 'normal ecg'], 'code15': ['normal ecg', 'sinus tachycardia', 'left bundle branch block']}
#
# Exp2 untrained classes:
# 2
# {'sph': ['t-wave abnormality', 'ventricular premature complex(es)', 'right bundle-branch block', 'atrial premature complex(es)', 'st deviation', 'low voltage', 'st deviation with t-wave change', 'sinus bradycardia', 'atrial fibrillation', 'incomplete right bundle-branch block'], 'code15': ['1st degree AV block', 'right bundle branch block', 'atrial fibrillation', 'sinus bradycardia']}

# %%
import lib.datasets.ptb_xl
import lib.datasets.georgia
import lib.datasets.ningbo
import lib.datasets.sph
import lib.datasets.code15

import pandas as pd

# %%
def calsses_from_captions(captions, threshold=100):
    all_classes = [name.strip() for caption in captions for name in caption.strip().split(',')]
    counts = pd.Series(all_classes).value_counts()
    return counts
    classes = counts[counts >= threshold].index.to_list()
    classes = sorted(classes)
    return classes

# %%
datasets = ['ptb_xl', 'ningbo', 'georgia', 'sph', 'code15']
dfs = list()

for ds in datasets:
    df = lib.datasets.__dict__[ds].load_df()
    dfs.append(df)

# %%
classes = list()
for df in dfs:
    classes += list(calsses_from_captions(df['label'], threshold=1).index.values)
classes = sorted(list(set([class_.lower().strip() for class_ in classes])))
classes = pd.DataFrame(classes)
classes = classes.set_index(0)

# %%
for ds, df in zip(datasets, dfs):
    classes[f'{ds}_counts'] = calsses_from_captions(df['label'], threshold=1)
classes = classes.fillna(0).astype('int32')

# %%
classes
# Out:
#                                    ptb_xl_counts  ningbo_counts  \
# 0
#                                                0            132
# 1st degree av block                          797            893
# 2:1 av block                                   0              0
# 2nd degree av block                           14             58
# abnormal qrs                                   0              0
# ...                                          ...            ...
# ventricular premature beats                    0              0
# ventricular premature complex(es)              0              0
# ventricular trigeminy                         20              0
# wandering atrial pacemaker                     0              0
# wolff parkinson white pattern                 80             68
#
#                                    georgia_counts  sph_counts  code15_counts
# 0
#                                                 0           0         308004
# 1st degree av block                           769           0              0
# 2:1 av block                                    0          35              0
# 2nd degree av block                            23           0              0
# abnormal qrs                                    0           0              0
# ...                                           ...         ...            ...
# ventricular premature beats                   357           0              0
# ventricular premature complex(es)               0        1067              0
# ventricular trigeminy                           1           0              0
# wandering atrial pacemaker                      7           0              0
# wolff parkinson white pattern                   2           0              0
#
# [122 rows x 5 columns]

# %%
cols = list()
for ds in datasets:
    classes[f'{ds}_class'] = classes.index.values
    cols.append(f'{ds}_class')
    cols.append(f'{ds}_counts')
classes = classes[cols]

# %%
classes = classes.reset_index(drop=True)

# %%
#for ds in datasets:
    #mask = classes[f'{ds}_counts'] == 0
    #classes[f'{ds}_counts'] = classes[f'{ds}_counts'].apply(str)
    #classes.loc[mask, f'{ds}_counts'] = ''
    #classes.loc[mask, f'{ds}_class'] = ''

# %%
classes.to_csv('data.csv')
