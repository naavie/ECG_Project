# %%
import pandas as pd

import lib.iterstrat
import lib.datasets

# %%
class_df = pd.read_csv('classes_for_experiments_v2.csv')
class_df.head()
# Out:
#             class_name  ptb_xl  ningbo  georgia  sph  code15     status  \
# 0                  NaN       0     132        0    0  308004    no eval
# 1  1st degree av block     797     893      769    0    5716  zero-shot
# 2         2:1 av block       0       0        0   35       0    no eval
# 3  2nd degree av block      14      58       23    0       0    no eval
# 4         abnormal qrs    3389       0        0    0       0      train
#
#     rename_to
# 0  normal ecg
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
def fix_names(class_df, threshold=150):
    datasets = ['ptb_xl', 'ningbo', 'georgia', 'sph', 'code15']
    
    for index, rename_to in class_df['rename_to'].items():
        if not pd.isna(rename_to):
            rename_to_index = class_df[class_df['class_name'] == rename_to]
            assert rename_to_index.shape[0] == 1
            rename_to_index = rename_to_index.index.values[0]
            class_df.loc[rename_to_index, datasets] += class_df.loc[index, datasets]

    class_fixing_dict = class_df[~class_df['rename_to'].isna()].set_index('class_name')['rename_to'].to_dict()

    class_df = class_df[class_df['rename_to'].isna()]
    zeroshot_classes = class_df[class_df['status'] == 'zero-shot']
    class_df = class_df[class_df['status'] != 'zero-shot']

    train_classes_mask = (class_df['ptb_xl'] >= threshold) & (class_df['class_name'] != 'normal ecg')
    train_classes = class_df[train_classes_mask]
    noteval_classes = class_df[~train_classes_mask]
    return train_classes, noteval_classes, zeroshot_classes, class_fixing_dict


train_classes, noteval_classes, zeroshot_classes, class_fixing_dict = fix_names(class_df)

# %%
df = lib.datasets.ptb_xl.load_df()

# %%
df['dataset'] = 'ptb_xl'

# %%
class_fixing_dict
# Out:
# {nan: 'normal ecg',
#  'anterior mi': 'anterior myocardial infarction',
#  'atrial premature complex(es)': 'atrial premature complexes',
#  'bradycardia': 'sinus bradycardia',
#  'complete (third-degree)': 'complete heart block',
#  'extensive anterior mi': 'anterior myocardial infarction',
#  'incomplete right bundle-branch block': 'incomplete right bundle branch block',
#  'junctional escape complex(es)': 'junctional escape',
#  'junctional premature complex(es)': 'junctional premature complex',
#  'left bundle-branch block': 'left bundle branch block',
#  'left-axis deviation': 'left axis deviation',
#  'low voltage': 'low qrs voltages',
#  'right bundle-branch block': 'right bundle branch block',
#  'right-axis deviation': 'right axis deviation',
#  'second-degree av block': '2nd degree av block',
#  'sinus rhythm': 'normal ecg',
#  't-wave abnormality': 't wave abnormal',
#  'ventricular premature complex(es)': 'ventricular premature beats'}

# %%
def prepare_df(df, train_classes, zeroshot_classes, class_fixing_dict):
    def fix_caption(caption):
        if caption == '':
            return 'normal ecg'
        split = caption.lower().strip().split(', ')
        fixed_caption = list()
        for class_ in split:
            class_ = class_.strip()
            if class_ in class_fixing_dict:
                class_ = class_fixing_dict[class_]
            fixed_caption.append(class_)

        if len(fixed_caption) > 1 and 'normal ecg' in fixed_caption:
            fixed_caption.remove('normal ecg')
        return ', '.join(fixed_caption)

    df['fixed_label'] = df['label'].apply(fix_caption)
    for class_ in train_classes['class_name'].values:
        df[class_] = df['fixed_label'].apply(lambda x: class_ in x)

    for class_ in zeroshot_classes['class_name'].values:
        df[class_] = df['fixed_label'].apply(lambda x: class_ in x)   

    return df

df = prepare_df(df, train_classes, zeroshot_classes, class_fixing_dict)

# %%
params = dict()
params['TARGETS'] = train_classes['class_name'].to_list()# + zeroshot_classes['class_name'].to_list()
params['SEED'] = 333

# %%
valid_mask = lib.iterstrat.short_valid_split(df, params, split=5)

# %%
df['split'] = valid_mask

# %%
for split in range(5):
    subdf = df[df['split'] == split]
    print(subdf[params['TARGETS']].sum())
    print()
    print()
# Out:
# abnormal qrs                                         673
# anterior myocardial infarction                        77
# complete right bundle branch block                   327
# indeterminate cardiac axis                            22
# inferior ischaemia                                    44
# left anterior fascicular block                       319
# left atrial enlargement                               87
# left axis deviation                                 1023
# left posterior fascicular block                       39
# left ventricular hypertrophy                         449
# low qrs voltages                                      39
# myocardial infarction                               1091
# myocardial ischemia                                  411
# nonspecific intraventricular conduction disorder     166
# nonspecific st t abnormality                          76
# pacing rhythm                                         56
# premature atrial contraction                          80
# prolonged pr interval                                 61
# qwave abnormal                                       101
# right axis deviation                                  77
# s t changes                                          171
# sinus arrhythmia                                     183
# st depression                                        187
# supraventricular premature beats                      34
# t wave abnormal                                      486
# t wave inversion                                      59
# ventricular ectopics                                 227
# dtype: int64
#
#
# abnormal qrs                                         696
# anterior myocardial infarction                        62
# complete right bundle branch block                   350
# indeterminate cardiac axis                            32
# inferior ischaemia                                    44
# left anterior fascicular block                       344
# left atrial enlargement                               95
# left axis deviation                                 1048
# left posterior fascicular block                       34
# left ventricular hypertrophy                         440
# low qrs voltages                                      38
# myocardial infarction                               1116
# myocardial ischemia                                  437
# nonspecific intraventricular conduction disorder     166
# nonspecific st t abnormality                          75
# pacing rhythm                                         61
# premature atrial contraction                          71
# prolonged pr interval                                 85
# qwave abnormal                                       103
# right axis deviation                                  58
# s t changes                                          156
# sinus arrhythmia                                     144
# st depression                                        196
# supraventricular premature beats                      29
# t wave abnormal                                      455
# t wave inversion                                      44
# ventricular ectopics                                 255
# dtype: int64
#
#
# abnormal qrs                                         668
# anterior myocardial infarction                        61
# complete right bundle branch block                   322
# indeterminate cardiac axis                            41
# inferior ischaemia                                    50
# left anterior fascicular block                       316
# left atrial enlargement                               82
# left axis deviation                                 1020
# left posterior fascicular block                       34
# left ventricular hypertrophy                         493
# low qrs voltages                                      35
# myocardial infarction                               1088
# myocardial ischemia                                  440
# nonspecific intraventricular conduction disorder     147
# nonspecific st t abnormality                          82
# pacing rhythm                                         68
# premature atrial contraction                          79
# prolonged pr interval                                 63
# qwave abnormal                                       124
# right axis deviation                                  65
# s t changes                                          168
# sinus arrhythmia                                     157
# st depression                                        205
# supraventricular premature beats                      30
# t wave abnormal                                      452
# t wave inversion                                      71
# ventricular ectopics                                 220
# dtype: int64
#
#
# abnormal qrs                                         673
# anterior myocardial infarction                        64
# complete right bundle branch block                   326
# indeterminate cardiac axis                            30
# inferior ischaemia                                    42
# left anterior fascicular block                       320
# left atrial enlargement                               80
# left axis deviation                                 1024
# left posterior fascicular block                       44
# left ventricular hypertrophy                         534
# low qrs voltages                                      37
# myocardial infarction                               1092
# myocardial ischemia                                  468
# nonspecific intraventricular conduction disorder     151
# nonspecific st t abnormality                          82
# pacing rhythm                                         51
# premature atrial contraction                          84
# prolonged pr interval                                 71
# qwave abnormal                                       112
# right axis deviation                                  76
# s t changes                                          131
# sinus arrhythmia                                     146
# st depression                                        205
# supraventricular premature beats                      29
# t wave abnormal                                      471
# t wave inversion                                      65
# ventricular ectopics                                 231
# dtype: int64
#
#
# abnormal qrs                                         679
# anterior myocardial infarction                        90
# complete right bundle branch block                   334
# indeterminate cardiac axis                            31
# inferior ischaemia                                    39
# left anterior fascicular block                       327
# left atrial enlargement                               83
# left axis deviation                                 1031
# left posterior fascicular block                       26
# left ventricular hypertrophy                         443
# low qrs voltages                                      33
# myocardial infarction                               1099
# myocardial ischemia                                  419
# nonspecific intraventricular conduction disorder     159
# nonspecific st t abnormality                          66
# pacing rhythm                                         60
# premature atrial contraction                          84
# prolonged pr interval                                 60
# qwave abnormal                                       108
# right axis deviation                                  67
# s t changes                                          144
# sinus arrhythmia                                     142
# st depression                                        216
# supraventricular premature beats                      35
# t wave abnormal                                      481
# t wave inversion                                      55
# ventricular ectopics                                 221
# dtype: int64
