# %%
from lib.default_params import CFG
from lib.exp1_train import exp1_train

# %%
ecg_encoder_channels = [(32, 32, 64, 64, 128, 256), 
                        (32, 32, 64, 64, 128, 128, 256)]

ecg_encoder_kernels = [(7, 7, 5, 5, 3, 3),
                       (7, 7, 5, 5, 3, 3, 3)]

ecg_linear_size = [128, 256]
ecg_embedding_size = [256, 768]

# %%
for ch, kr, ecg_lin, ecg_emb in zip(ecg_encoder_channels, ecg_encoder_kernels, ecg_linear_size,  ecg_embedding_size):
    for seed in [42, 43, 44]:
        CFG.seed = seed
        CFG.ecg_encoder_channels = ch
        CFG.ecg_encoder_kernels = kr
        CFG.ecg_linear_size = ecg_lin
        CFG.ecg_emb = ecg_emb
        CFG.device = 'cuda:3'
        exp1_train(CFG)
# Out:
# Train/valid/test classes counts: 27 11 12
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4368/4368 [00:04<00:00, 1035.01it/s]
# Epoch: 1
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:14<00:00,  3.60it/s]
# Train: 0.5977389827989334 0.12852100228430127
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:06<00:00,  2.83it/s]
# Valid: 0.6140433914693278 0.2406679930533474
# Epoch: 2
# ...
