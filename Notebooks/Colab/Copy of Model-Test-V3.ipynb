# %% [markdown]
# # ClinicalBERT

# %%
# General imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import sys
from tqdm import tqdm
import ast
from scipy.signal import resample
import json
import warnings
import time

# Matlab/WFDB files
import scipy.io as sio

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 53.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.3-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 37.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.19.3 safetensors-0.4.0 tokenizers-0.15.0 transformers-4.35.2

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn as nn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to training folder within PhysioNet dataset
PhysioNet_PATH = '/content/drive/MyDrive/ECG Project (Shared Folder)/Datasets/physionet.org/files/challenge-2021/1.0.3/training'
PhysioNet_PATH
# Out:
# '/content/drive/MyDrive/ECG Project (Shared Folder)/Datasets/physionet.org/files/challenge-2021/1.0.3/training'

# %%
PyFiles_PATH = '/content/drive/MyDrive/ECG Project (Shared Folder)/PyFiles'
PyFiles_PATH
# Out:
# '/content/drive/MyDrive/ECG Project (Shared Folder)/PyFiles'

# %%
sys.path.append(PyFiles_PATH)

# %%
from helper_functions import *
from dataset import PhysioNetDataset

# %%
train_set = PhysioNetDataset(PhysioNet_PATH, train = True)
val_set = PhysioNetDataset(PhysioNet_PATH, train = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-753baafda217> in <cell line: 1>()
# ----> 1 train_set = PhysioNetDataset(PhysioNet_PATH, train = True)
#       2 val_set = PhysioNetDataset(PhysioNet_PATH, train = False)
#
# /content/drive/MyDrive/ECG Project (Shared Folder)/PyFiles/dataset.py in __init__(self, dataset_path, train)
#      52                     else:
#      53                         if os.path.isdir(sub_folder_path):
# ---> 54                             for file in os.listdir(sub_folder_path):
#      55                                 # Get all .hea files
#      56                                 if file.endswith('.hea'):
#
# KeyboardInterrupt:

# %%
# Header Data + Mapped SNOWMED-CT Codes
processed_train_df = pd.read_csv('/content/drive/MyDrive/ECG Project (Shared Folder)/processed_train_set_records.csv')
processed_val_df = pd.read_csv('/content/drive/MyDrive/ECG Project (Shared Folder)/processed_val_set_records.csv')

# %%
processed_train_df['dx_modality'][0]
# Out:
# "['atrial fibrillation', 'right bundle branch block', 't wave abnormal']"

# %%
processed_train_df.head(2)
# Out:
#   recording_number recording_file  num_leads  sampling_frequency  num_samples  \
# 0          JS00001    JS00001.mat         12                 500         5000
# 1          JS00002    JS00002.mat         12                 500         5000
#
#     age     sex                                      dx       rx       hx  \
# 0  85.0    Male  ['164889003', '59118001', '164934002']  Unknown  Unknown
# 1  59.0  Female              ['426177001', '164934002']  Unknown  Unknown
#
#    ... lead_10_lead_name lead_11_file  lead_11_adc_gain lead_11_units  \
# 0  ...                 0  JS00001.mat            1000.0            mV
# 1  ...                 0  JS00002.mat            1000.0            mV
#
#    lead_11_adc_resolution  lead_11_adc_zero  lead_11_initial_value  \
# 0                      16                 0                    527
# 1                      16                 0                      0
#
#    lead_11_checksum  lead_11_lead_name  \
# 0             32579                  0
# 1             31542                  0
#
#                                          dx_modality
# 0  ['atrial fibrillation', 'right bundle branch b...
# 1           ['sinus bradycardia', 't wave abnormal']
#
# [2 rows x 108 columns]

# %% [markdown]
# # TextEncoder()
#
# Create a class, ```TextEncoder()``` that is used to convert the description of the (dx_modality) diagnosis class into embeddings using the ClinicalBERT model.
#
# - Input should be a concatenated using comma or blank space string of diagnoses/dx_modality per ECG signal.
# - Use processed CSV files (dx_modality vs dx_modality, age, etc together)
# - Frozen weights (since it's already pretrained)

# %%
class TextEncoder:
    def __init__(self):
        self.tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
        self.model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

    def encode(self, text_list):
        # Check if text_list is a string representation of a list
        if isinstance(text_list, str):
            text_list = ast.literal_eval(text_list)
        # Convert list of strings to a single string
        text = ', '.join(text_list)
        # Tokenize text
        inputs = self.tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
        # Get embeddings from ClinicalBERT model
        with torch.no_grad():
            embeddings = self.model(**inputs).last_hidden_state
        # Average the embeddings to get single vector per each input
        embeddings = torch.mean(embeddings, dim=1)
        return embeddings

# %%
text_encoder = TextEncoder()
embeddings = text_encoder.encode(processed_train_df['dx_modality'][0])
print(embeddings.size())
# Out:
# (…)io_ClinicalBERT/resolve/main/config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# (…)/Bio_ClinicalBERT/resolve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# torch.Size([1, 768])

# %%
embeddings
# Out:
# tensor([[ 1.8975e-01,  3.0864e-01, -4.8170e-02,  1.9149e-01,  2.7236e-01,
#           1.8960e-01, -6.3694e-02,  1.6969e-01,  1.7664e-01,  1.3202e-01,
#          -1.5042e-01,  5.0794e-01, -7.3957e-02,  2.9992e-01, -2.1831e-01,
#          -1.3088e-01,  1.1179e-01,  1.9628e-02, -1.9350e-01, -1.6476e-01,
#           8.1238e-02, -4.2498e-01, -3.8750e-01, -4.7243e-02, -1.5559e-02,
#          -2.4554e-01, -1.0310e-01,  5.7794e-01,  1.4504e-01,  1.6382e-01,
#          -2.1807e-02,  7.4254e-03, -2.5811e-01,  3.3975e-01,  1.6474e-01,
#           1.2412e-01, -8.9964e-02, -6.1442e-03,  1.3661e-01,  1.2153e-01,
#           3.6225e-01,  6.1826e-02, -3.7872e-01,  2.8434e-01, -1.3252e-01,
#          -2.9651e-01,  6.7283e-02, -6.6552e-02, -2.9479e-01, -1.2505e-02,
#           1.6438e-01,  3.5855e-01,  3.9261e-01,  5.9356e-02,  3.6884e-01,
#          -1.4099e-01, -3.9989e-01, -3.2891e-01, -3.4848e-01,  3.2186e-01,
#           1.5459e-02,  8.9985e-02, -1.2571e-01,  1.9153e-01,  2.4583e-01,
#          -7.6325e-02,  3.0472e-01,  1.5178e-01, -1.6549e-01, -1.7945e-01,
#          -4.4721e-01, -1.6307e-01,  7.9885e-02,  7.3832e-02,  1.0414e-01,
#          -8.1312e-02,  2.8213e-01,  4.5783e-02,  2.6955e-01,  2.9032e-01,
#           5.5847e-01, -1.8811e-01, -6.3565e-02,  3.3999e-01, -5.3417e-01,
#          -1.3656e-02, -1.3957e-01, -8.8256e-02, -2.2777e-01,  5.1970e-01,
#          -1.8328e-02, -4.1747e-01, -1.6557e-01, -1.2924e-01,  7.4920e-03,
#           6.4578e-02, -1.2784e-01,  2.2697e-01, -1.9224e-01,  6.7481e-02,
#          -1.2423e-01, -6.5538e-02,  8.1540e-02, -4.6044e-01,  2.3196e-01,
#           4.2431e-01, -2.9876e-01,  5.9968e-02,  1.0156e-01,  1.2270e-01,
#          -2.8948e-01,  9.2972e-02, -1.7820e-01,  3.1359e-02,  1.5949e-01,
#          -5.5430e-01,  2.6795e-01,  8.0159e-02,  1.0347e-01,  6.2230e-02,
#           4.5063e-01, -5.0316e-01, -5.1254e-02]])

# %% [markdown]
# # ECGEncoder()
#
# - Input is ECG signal, output will be embeddings of ECG signal
# - This is going to be model in model.py
# - Model weights are updated iteratively
# - optimizer = torch.optim.Adam(clip_model.ECGEncoder.parameters())

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
class OneDimCNN(nn.Module):
    def __init__(self, num_classes):
        super(OneDimCNN, self).__init__()

        # Layer 1
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm1d(32)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)

        # Layer 2
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)

        # Layer 3
        self.conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        # Layer 4
        self.conv4 = nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm1d(256)
        self.relu4 = nn.ReLU()
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)

        # Fully Connected Layer 1
        self.fc1 = nn.Linear(79872, 128)
        self.relu5 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.5)

        # Fully Connected Layer 2
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        # Layer 1
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.pool1(x)

        # Layer 2
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.pool2(x)

        # Layer 3
        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu3(x)
        x = self.pool3(x)

        # Layer 4
        x = self.conv4(x)
        x = self.bn4(x)
        x = self.relu4(x)
        x = self.pool4(x)

        # Flatten the tensor
        x = x.view(x.size(0), -1)
        # print(x.shape)

        # Fully Connected Layer 1
        x = self.fc1(x)
        x = self.relu5(x)
        x = self.dropout1(x)

        # Fully Connected Layer 2
        x = self.fc2(x)

        return x

# %%
class ECGEncoder(OneDimCNN):
    def __init__(self, num_classes):
        super(ECGEncoder, self).__init__(num_classes)
        self.fc3 = nn.Linear(126, 768)  # New linear layer

    def encode(self, signal):
        signal = torch.tensor(signal, dtype=torch.float).unsqueeze(0)
        embedding = self.forward(signal)
        return self.fc3(embedding)  # Apply the new linear layer

# %%
type(train_set[0][1]['val'])
# Out:
# numpy.ndarray

# %%
train_set[0][1]['val']
# Out:
# array([[ -49.41174209,  -49.41174209,  -49.41174209, ...,    3.26986681,
#            6.65822132,    4.35320015],
#        [  39.23760431,   39.23760431,   39.23760431, ...,  -45.89316397,
#          -44.94818514,  -42.39476713],
#        [  95.17413779,   95.17413779,   95.17413779, ..., -112.12670284,
#         -112.96003617, -116.70843301]])

# %%
# Define the number of classes
num_classes = 126

# Create an instance of the model
ecg_encoder = ECGEncoder(num_classes)

# Convert the numpy array to a PyTorch tensor
input_data = torch.from_numpy(train_set[60000][1]['val']).float()

# Add an extra dimension for the batch size
input_data = input_data.unsqueeze(0)

# Convert the model's weights to Float
ecg_encoder = ecg_encoder.float()

# Pass the data through the model
output = ecg_encoder(input_data)

print(output)
# Out:
# tensor([[ 0.0782,  0.3507,  0.4124, -0.0518, -0.2030, -0.3175,  0.5087,  0.0060,
#          -0.7707,  0.2363, -0.0559, -0.5044, -0.5819, -0.0828,  0.0036,  0.1545,
#           0.2404,  0.3532, -0.0037, -0.2324,  0.0248, -0.0734,  0.0640, -0.1215,
#           0.1172,  0.2116, -0.4930, -0.4360,  0.1286, -0.2000,  0.3085,  0.7351,
#           0.1531,  0.3013, -0.1597,  0.2680, -0.3177,  0.1918, -0.5725, -0.0113,
#          -0.2665,  0.0122,  0.1794, -0.2652, -0.0538, -0.0325,  0.1387,  0.1452,
#           0.0522,  0.2749,  0.4686, -0.1010, -0.3231,  0.0459,  0.0438, -0.1950,
#          -0.4089,  0.3040, -0.0319, -0.1998, -0.1212,  0.1492,  0.8501,  0.1538,
#           0.0512,  0.0891, -0.0682, -0.2538, -0.1318,  0.0538, -0.2148,  0.5314,
#          -0.3847,  0.2059, -0.2431, -0.2679, -0.0384, -0.1250,  0.1306,  0.1732,
#          -0.5033,  0.1928,  0.1803,  0.1711,  0.3875,  0.4904,  0.2149,  0.2390,
#          -0.4808,  0.1219,  0.3235,  0.3111, -0.1651, -0.3142,  0.2434,  0.2042,
#           0.0359,  0.3012, -0.0602, -0.5070, -0.0248,  0.1258, -0.2522,  0.1991,
#           0.0363,  0.2120, -0.0702,  0.3927, -0.1437, -0.0783, -0.2532,  0.0595,
#           0.0387,  0.0987,  0.3973,  0.2977,  0.1278,  0.1830, -0.2506, -0.0064,
#           0.6390, -0.3973,  0.1186,  0.0525, -0.2866,  0.1699]],
#        grad_fn=<AddmmBackward0>)

# %%
# Convert the model's weights to Float
ecg_encoder = ecg_encoder.float()

# Set the model in evaluation mode
ecg_encoder.eval()

# Pass the data through the model
output = ecg_encoder(input_data)

print(output)
# Out:
# tensor([[ 0.0089,  0.0508,  0.0747,  0.0004, -0.0709, -0.0121, -0.0174,  0.0108,
#          -0.0159,  0.0286,  0.0462, -0.1531,  0.0912,  0.0005,  0.0661,  0.0893,
#           0.0438,  0.1017, -0.0086, -0.0439,  0.0205, -0.0163,  0.0093,  0.0031,
#           0.0023,  0.1072, -0.0517,  0.1196,  0.0267,  0.0081,  0.0102, -0.1114,
#          -0.0709, -0.0173,  0.0147, -0.1080,  0.0417, -0.0744, -0.0630,  0.1390,
#           0.0279, -0.0136, -0.0302,  0.0075, -0.0056, -0.0309,  0.0641,  0.0728,
#          -0.0152,  0.0285, -0.0273,  0.0432,  0.1088, -0.0714, -0.0908, -0.0648,
#          -0.0714, -0.0346, -0.0180, -0.0974, -0.0882, -0.0979, -0.0625, -0.0864,
#           0.0301, -0.0385, -0.0454, -0.1070,  0.0440,  0.0862,  0.0046,  0.0805,
#          -0.0724, -0.0606, -0.1373, -0.0198,  0.0376,  0.0421,  0.0445, -0.0783,
#           0.1198, -0.0871, -0.0126, -0.0576, -0.0755, -0.0223, -0.0407,  0.0511,
#           0.1379,  0.0229, -0.0920, -0.0784,  0.0149,  0.0016,  0.0568, -0.0786,
#           0.0563,  0.1018,  0.0392, -0.0603, -0.0084, -0.0972, -0.0516, -0.0002,
#           0.0722, -0.0145, -0.1103,  0.0071, -0.0422,  0.0068,  0.1084,  0.0381,
#          -0.0551,  0.0236, -0.0230,  0.0327, -0.0121, -0.0099,  0.1136,  0.0215,
#           0.1369,  0.0581,  0.1176, -0.0137,  0.0187, -0.0163]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# # InstanceSelecter()
#
# - positive_instances are where the ECG embedding and dx_modality embedding align (from the same file/reading)
# - negative_instances are where these two embeddings do not align
# - filter out text embeddings that are the same or equal to the positive_instances

# %%
from tqdm import tqdm

class InstanceSelector:
    def __init__(self, train_set, processed_train_df, text_encoder, ecg_encoder):
        self.train_set = train_set
        self.processed_train_df = processed_train_df
        self.text_encoder = text_encoder
        self.ecg_encoder = ecg_encoder

    # def get_positive_instances(self):
    #     positive_instances = []
    #     for i in tqdm(range(len(self.train_set)), desc="Generating positive instances"):
    #         ecg_embedding = self.ecg_encoder.encode(self.train_set[i][1]['val'])
    #         dx_modality_embedding = self.text_encoder.encode(self.processed_train_df['dx_modality'][i])
    #         if torch.all(torch.eq(ecg_embedding, dx_modality_embedding)):
    #             positive_instances.append((ecg_embedding, dx_modality_embedding))
    #     return positive_instances

    def get_negative_instances(self):
        negative_instances = []
        positive_instances = self.get_positive_instances()
        for i in tqdm(range(len(self.train_set)), desc="Generating negative instances"):
            ecg_embedding = self.ecg_encoder.encode(self.train_set[i][1]['val'])
            for j in range(len(self.processed_train_df)):
                if i != j:
                    dx_modality_embedding = self.text_encoder.encode(self.processed_train_df['dx_modality'][j])
                    if not any(torch.all(torch.eq(ecg_embedding, pos[1])) for pos in positive_instances):
                        negative_instances.append((ecg_embedding, dx_modality_embedding))
        return negative_instances

# %%
text_encoder = TextEncoder()
ecg_encoder = ECGEncoder(num_classes=126)  # Assuming you have this class defined

# %%
instance_selector = InstanceSelector(train_set, processed_train_df, text_encoder, ecg_encoder)

# %%
positive_instances = instance_selector.get_positive_instances()

# %%
negative_instances = instance_selector.get_negative_instances()

# %% [markdown]
# # CLIPModel

# %%
class CLIPModel(nn.Module):
    def __init__(self, train_set, processed_train_df):
        super(CLIPModel, self).__init__()
        self.ecg_encoder = ECGEncoder(num_classes=126)  # Initialize ECGEncoder
        self.text_encoder = TextEncoder()  # Initialize TextEncoder
        self.instance_selector = InstanceSelector(train_set, processed_train_df, self.text_encoder, self.ecg_encoder)

    def forward(self, ecgs, diagnoses):
        ecgs_embeddings = self.ecg_encoder(ecgs)
        diagnoses_embeddings = self.text_encoder.encode(diagnoses)
        positive_instances = self.instance_selector.get_positive_instances()
        negative_instances = self.instance_selector.get_negative_instances()
        # Compute loss based on whether the pair of embeddings is a positive or negative instance
        loss = sum(F.cosine_similarity(ecgs_embeddings[i], diagnoses_embeddings[i]) for i in range(len(ecgs)) if (ecgs_embeddings[i], diagnoses_embeddings[i]) in positive_instances) \
             - sum(F.cosine_similarity(ecgs_embeddings[i], diagnoses_embeddings[i]) for i in range(len(ecgs)) if (ecgs_embeddings[i], diagnoses_embeddings[i]) in negative_instances)
        return loss

# %% [markdown]
# Example of how the CLIP-like model works:

# %% [markdown]
# Creating small data subsets for training example:
#
# - 100 records only for train_set
# - 100 records only for processed_train_df

# %%
sample_train_set_100 = train_set[:100]
sample_processed_train_df_100 = processed_train_df.iloc[:100]

# %%
len(sample_processed_train_df_100) , len(sample_train_set_100)
# Out:
# (100, 100)

# %%
# Initialize model
model = CLIPModel(sample_train_set_100, sample_processed_train_df_100)
# Initialize optimizer
optimizer = torch.optim.Adam(model.ecg_encoder.parameters())

num_params = sum(p.numel() for p in model.parameters())
print("Number of parameters: ", num_params)
# Out:
# Number of parameters:  10468286

# %%
# Training params
num_epochs = 3

# %%
# Initialize a list to store the loss at each step
losses = []

# Training loop
for epoch in range(num_epochs):
    # Add a progress bar for the inner loop
    for i in tqdm(range(len(sample_train_set_100)), desc=f"Training epoch {epoch+1}/{2}"):
        # Get ECGs and diagnoses from training set
        ecgs = sample_train_set_100[i][1]['val']
        diagnoses = sample_processed_train_df_100['dx_modality'][i]

        # Convert ECGs to tensor and add a dimension for batch size
        ecgs = torch.from_numpy(ecgs).float().unsqueeze(0)

        # Forward pass
        loss = model(ecgs, diagnoses)

        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Save the loss to a variable
        losses.append(loss.item())

    print ('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))

# Save the model checkpoint after training
torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Training epoch 1/2:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating positive instances:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating positive instances:   1%|          | 1/100 [00:00<00:29,  3.37it/s]
# Generating positive instances:   2%|▏         | 2/100 [00:00<00:29,  3.32it/s]
# Generating positive instances:   3%|▎         | 3/100 [00:00<00:25,  3.81it/s]
# Generating positive instances:   4%|▍         | 4/100 [00:01<00:27,  3.43it/s]
# Generating positive instances:   5%|▌         | 5/100 [00:01<00:28,  3.33it/s]
# Generating positive instances:   6%|▌         | 6/100 [00:01<00:26,  3.53it/s]
# Generating positive instances:   7%|▋         | 7/100 [00:02<00:26,  3.53it/s]
# Generating positive instances:   8%|▊         | 8/100 [00:02<00:27,  3.36it/s]
# Generating positive instances:   9%|▉         | 9/100 [00:02<00:28,  3.18it/s]
# Generating positive instances:  10%|█         | 10/100 [00:03<00:33,  2.69it/s]
# Generating positive instances:  11%|█         | 11/100 [00:03<00:29,  3.00it/s]
# Generating positive instances:  12%|█▏        | 12/100 [00:03<00:23,  3.71it/s]
# Generating positive instances:  13%|█▎        | 13/100 [00:03<00:20,  4.34it/s]
# Generating positive instances:  14%|█▍        | 14/100 [00:03<00:16,  5.16it/s]
# Generating positive instances:  15%|█▌        | 15/100 [00:03<00:15,  5.62it/s]
# Generating positive instances:  16%|█▌        | 16/100 [00:04<00:13,  6.35it/s]
# Generating positive instances:  17%|█▋        | 17/100 [00:04<00:12,  6.76it/s]
# Generating positive instances:  18%|█▊        | 18/100 [00:04<00:12,  6.82it/s]
# Generating positive instances:  19%|█▉        | 19/100 [00:04<00:11,  7.29it/s]
# Generating positive instances:  21%|██        | 21/100 [00:04<00:09,  8.26it/s]
# Generating positive instances:  22%|██▏       | 22/100 [00:04<00:09,  8.32it/s]
# Generating positive instances:  23%|██▎       | 23/100 [00:04<00:09,  8.43it/s]
# Generating positive instances:  24%|██▍       | 24/100 [00:05<00:09,  7.87it/s]
# Generating positive instances:  25%|██▌       | 25/100 [00:05<00:09,  8.02it/s]
# Generating positive instances:  26%|██▌       | 26/100 [00:05<00:09,  8.07it/s]
# Generating positive instances:  27%|██▋       | 27/100 [00:05<00:08,  8.18it/s]
# Generating positive instances:  28%|██▊       | 28/100 [00:05<00:08,  8.01it/s]
# Generating positive instances:  29%|██▉       | 29/100 [00:05<00:08,  8.36it/s]
# Generating positive instances:  30%|███       | 30/100 [00:05<00:08,  8.65it/s]
# Generating positive instances:  31%|███       | 31/100 [00:05<00:07,  8.87it/s]
# Generating positive instances:  32%|███▏      | 32/100 [00:05<00:08,  8.45it/s]
# Generating positive instances:  33%|███▎      | 33/100 [00:06<00:07,  8.72it/s]
# Generating positive instances:  34%|███▍      | 34/100 [00:06<00:07,  8.86it/s]
# Generating positive instances:  35%|███▌      | 35/100 [00:06<00:07,  8.16it/s]
# Generating positive instances:  36%|███▌      | 36/100 [00:06<00:07,  8.43it/s]
# Generating positive instances:  37%|███▋      | 37/100 [00:06<00:07,  8.71it/s]
# Generating positive instances:  38%|███▊      | 38/100 [00:06<00:07,  8.51it/s]
# Generating positive instances:  39%|███▉      | 39/100 [00:06<00:06,  8.83it/s]
# Generating positive instances:  40%|████      | 40/100 [00:06<00:07,  7.96it/s]
# Generating positive instances:  41%|████      | 41/100 [00:07<00:07,  8.01it/s]
# Generating positive instances:  42%|████▏     | 42/100 [00:07<00:07,  7.97it/s]
# Generating positive instances:  43%|████▎     | 43/100 [00:07<00:07,  7.63it/s]
# Generating positive instances:  44%|████▍     | 44/100 [00:07<00:06,  8.08it/s]
# Generating positive instances:  45%|████▌     | 45/100 [00:07<00:06,  8.42it/s]
# Generating positive instances:  46%|████▌     | 46/100 [00:07<00:06,  8.41it/s]
# Generating positive instances:  47%|████▋     | 47/100 [00:07<00:06,  8.72it/s]
# Generating positive instances:  49%|████▉     | 49/100 [00:07<00:05,  8.76it/s]
# Generating positive instances:  50%|█████     | 50/100 [00:08<00:05,  8.89it/s]
# Generating positive instances:  51%|█████     | 51/100 [00:08<00:05,  8.96it/s]
# Generating positive instances:  52%|█████▏    | 52/100 [00:08<00:05,  9.05it/s]
# Generating positive instances:  53%|█████▎    | 53/100 [00:08<00:05,  8.91it/s]
# Generating positive instances:  54%|█████▍    | 54/100 [00:08<00:05,  9.01it/s]
# Generating positive instances:  55%|█████▌    | 55/100 [00:08<00:04,  9.28it/s]
# Generating positive instances:  56%|█████▌    | 56/100 [00:08<00:05,  8.70it/s]
# Generating positive instances:  57%|█████▋    | 57/100 [00:08<00:04,  8.75it/s]
# Generating positive instances:  59%|█████▉    | 59/100 [00:09<00:04,  9.36it/s]
# Generating positive instances:  61%|██████    | 61/100 [00:09<00:04,  9.19it/s]
# Generating positive instances:  62%|██████▏   | 62/100 [00:09<00:04,  9.03it/s]
# Generating positive instances:  63%|██████▎   | 63/100 [00:09<00:04,  9.01it/s]
# Generating positive instances:  64%|██████▍   | 64/100 [00:09<00:04,  8.27it/s]
# Generating positive instances:  66%|██████▌   | 66/100 [00:09<00:03,  8.70it/s]
# Generating positive instances:  68%|██████▊   | 68/100 [00:10<00:03,  8.03it/s]
# Generating positive instances:  69%|██████▉   | 69/100 [00:10<00:03,  8.22it/s]
# Generating positive instances:  70%|███████   | 70/100 [00:10<00:03,  8.04it/s]
# Generating positive instances:  71%|███████   | 71/100 [00:10<00:03,  7.70it/s]
# Generating positive instances:  72%|███████▏  | 72/100 [00:10<00:03,  8.06it/s]
# Generating positive instances:  73%|███████▎  | 73/100 [00:10<00:03,  8.36it/s]
# Generating positive instances:  74%|███████▍  | 74/100 [00:10<00:03,  8.24it/s]
# Generating positive instances:  75%|███████▌  | 75/100 [00:11<00:03,  7.50it/s]
# Generating positive instances:  76%|███████▌  | 76/100 [00:11<00:03,  7.94it/s]
# Generating positive instances:  77%|███████▋  | 77/100 [00:11<00:03,  7.57it/s]
# Generating positive instances:  78%|███████▊  | 78/100 [00:11<00:02,  7.53it/s]
# Generating positive instances:  79%|███████▉  | 79/100 [00:11<00:02,  7.94it/s]
# Generating positive instances:  80%|████████  | 80/100 [00:11<00:02,  8.04it/s]
# Generating positive instances:  81%|████████  | 81/100 [00:11<00:02,  8.01it/s]
# Generating positive instances:  82%|████████▏ | 82/100 [00:11<00:02,  8.36it/s]
# Generating positive instances:  83%|████████▎ | 83/100 [00:12<00:02,  7.89it/s]
# Generating positive instances:  84%|████████▍ | 84/100 [00:12<00:01,  8.27it/s]
# Generating positive instances:  85%|████████▌ | 85/100 [00:12<00:01,  8.35it/s]
# Generating positive instances:  86%|████████▌ | 86/100 [00:12<00:01,  8.23it/s]
# Generating positive instances:  87%|████████▋ | 87/100 [00:12<00:01,  7.42it/s]
# Generating positive instances:  88%|████████▊ | 88/100 [00:12<00:01,  7.87it/s]
# Generating positive instances:  89%|████████▉ | 89/100 [00:12<00:01,  7.78it/s]
# Generating positive instances:  90%|█████████ | 90/100 [00:12<00:01,  8.07it/s]
# Generating positive instances:  91%|█████████ | 91/100 [00:13<00:01,  8.43it/s]
# Generating positive instances:  92%|█████████▏| 92/100 [00:13<00:00,  8.48it/s]
# Generating positive instances:  93%|█████████▎| 93/100 [00:13<00:01,  6.86it/s]
# Generating positive instances:  94%|█████████▍| 94/100 [00:13<00:00,  6.92it/s]
# Generating positive instances:  95%|█████████▌| 95/100 [00:13<00:00,  6.53it/s]
# Generating positive instances:  96%|█████████▌| 96/100 [00:13<00:00,  6.41it/s]
# Generating positive instances:  97%|█████████▋| 97/100 [00:14<00:00,  6.40it/s]
# Generating positive instances:  98%|█████████▊| 98/100 [00:14<00:00,  6.03it/s]
# Generating positive instances:  99%|█████████▉| 99/100 [00:14<00:00,  6.10it/s]
# Generating positive instances: 100%|██████████| 100/100 [00:14<00:00,  6.89it/s]
#
# Generating positive instances:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating positive instances:   1%|          | 1/100 [00:00<00:20,  4.84it/s]
# Generating positive instances:   2%|▏         | 2/100 [00:00<00:19,  5.04it/s]
# Generating positive instances:   3%|▎         | 3/100 [00:00<00:18,  5.35it/s]
# Generating positive instances:   4%|▍         | 4/100 [00:00<00:19,  5.01it/s]
# Generating positive instances:   5%|▌         | 5/100 [00:00<00:17,  5.52it/s]
# Generating positive instances:   6%|▌         | 6/100 [00:01<00:16,  5.60it/s]
# Generating positive instances:   7%|▋         | 7/100 [00:01<00:15,  6.08it/s]
# Generating positive instances:   8%|▊         | 8/100 [00:01<00:14,  6.36it/s]
# Generating positive instances:   9%|▉         | 9/100 [00:01<00:14,  6.48it/s]
# Generating positive instances:  10%|█         | 10/100 [00:01<00:14,  6.11it/s]
# Generating positive instances:  11%|█         | 11/100 [00:01<00:14,  6.30it/s]
# Generating positive instances:  12%|█▏        | 12/100 [00:02<00:14,  6.12it/s]
# Generating positive instances:  13%|█▎        | 13/100 [00:02<00:15,  5.54it/s]
# Generating positive instances:  14%|█▍        | 14/100 [00:02<00:14,  5.89it/s]
# Generating positive instances:  15%|█▌        | 15/100 [00:02<00:15,  5.59it/s]
# Generating positive instances:  16%|█▌        | 16/100 [00:02<00:14,  5.83it/s]
# Generating positive instances:  17%|█▋        | 17/100 [00:02<00:14,  5.82it/s]
# Generating positive instances:  18%|█▊        | 18/100 [00:03<00:14,  5.50it/s]
# Generating positive instances:  19%|█▉        | 19/100 [00:03<00:14,  5.72it/s]
# Generating positive instances:  20%|██        | 20/100 [00:03<00:13,  6.05it/s]
# Generating positive instances:  21%|██        | 21/100 [00:03<00:12,  6.30it/s]
# Generating positive instances:  22%|██▏       | 22/100 [00:03<00:12,  6.32it/s]
# Generating positive instances:  23%|██▎       | 23/100 [00:03<00:12,  6.37it/s]
# Generating positive instances:  24%|██▍       | 24/100 [00:04<00:13,  5.62it/s]
# Generating positive instances:  25%|██▌       | 25/100 [00:04<00:13,  5.58it/s]
# Generating positive instances:  26%|██▌       | 26/100 [00:04<00:13,  5.33it/s]
# Generating positive instances:  27%|██▋       | 27/100 [00:04<00:13,  5.44it/s]
# Generating positive instances:  28%|██▊       | 28/100 [00:04<00:13,  5.36it/s]
# Generating positive instances:  29%|██▉       | 29/100 [00:05<00:12,  5.56it/s]
# Generating positive instances:  30%|███       | 30/100 [00:05<00:12,  5.64it/s]
# Generating positive instances:  31%|███       | 31/100 [00:05<00:12,  5.68it/s]
# Generating positive instances:  32%|███▏      | 32/100 [00:05<00:13,  5.22it/s]
# Generating positive instances:  33%|███▎      | 33/100 [00:05<00:12,  5.50it/s]
# Generating positive instances:  34%|███▍      | 34/100 [00:05<00:11,  5.86it/s]
# Generating positive instances:  35%|███▌      | 35/100 [00:06<00:11,  5.65it/s]
# Generating positive instances:  36%|███▌      | 36/100 [00:06<00:10,  5.96it/s]
# Generating positive instances:  37%|███▋      | 37/100 [00:06<00:10,  6.17it/s]
# Generating positive instances:  38%|███▊      | 38/100 [00:06<00:11,  5.63it/s]
# Generating positive instances:  39%|███▉      | 39/100 [00:06<00:09,  6.12it/s]
# Generating positive instances:  40%|████      | 40/100 [00:07<00:11,  5.26it/s]
# Generating positive instances:  41%|████      | 41/100 [00:07<00:11,  5.24it/s]
# Generating positive instances:  42%|████▏     | 42/100 [00:07<00:11,  5.17it/s]
# Generating positive instances:  43%|████▎     | 43/100 [00:07<00:11,  4.84it/s]
# Generating positive instances:  44%|████▍     | 44/100 [00:07<00:10,  5.43it/s]
# Generating positive instances:  45%|████▌     | 45/100 [00:07<00:09,  5.79it/s]
# Generating positive instances:  46%|████▌     | 46/100 [00:08<00:09,  5.80it/s]
# Generating positive instances:  47%|████▋     | 47/100 [00:08<00:08,  6.01it/s]
# Generating positive instances:  48%|████▊     | 48/100 [00:08<00:07,  6.55it/s]
# Generating positive instances:  49%|████▉     | 49/100 [00:08<00:08,  5.89it/s]
# Generating positive instances:  50%|█████     | 50/100 [00:08<00:08,  5.93it/s]
# Generating positive instances:  51%|█████     | 51/100 [00:08<00:08,  6.03it/s]
# Generating positive instances:  52%|█████▏    | 52/100 [00:09<00:07,  6.16it/s]
# Generating positive instances:  53%|█████▎    | 53/100 [00:09<00:07,  6.28it/s]
# Generating positive instances:  54%|█████▍    | 54/100 [00:09<00:07,  6.37it/s]
# Generating positive instances:  55%|█████▌    | 55/100 [00:09<00:06,  6.58it/s]
# Generating positive instances:  56%|█████▌    | 56/100 [00:09<00:07,  6.20it/s]
# Generating positive instances:  57%|█████▋    | 57/100 [00:09<00:06,  6.24it/s]
# Generating positive instances:  58%|█████▊    | 58/100 [00:09<00:06,  6.59it/s]
# Generating positive instances:  59%|█████▉    | 59/100 [00:10<00:06,  6.58it/s]
# Generating positive instances:  60%|██████    | 60/100 [00:10<00:05,  6.80it/s]
# Generating positive instances:  61%|██████    | 61/100 [00:10<00:06,  6.01it/s]
# Generating positive instances:  62%|██████▏   | 62/100 [00:10<00:06,  5.99it/s]
# Generating positive instances:  63%|██████▎   | 63/100 [00:10<00:06,  6.01it/s]
# Generating positive instances:  64%|██████▍   | 64/100 [00:11<00:07,  5.12it/s]
# Generating positive instances:  65%|██████▌   | 65/100 [00:11<00:06,  5.63it/s]
# Generating positive instances:  66%|██████▌   | 66/100 [00:11<00:06,  5.52it/s]
# Generating positive instances:  67%|██████▋   | 67/100 [00:11<00:05,  5.89it/s]
# Generating positive instances:  68%|██████▊   | 68/100 [00:11<00:06,  4.87it/s]
# Generating positive instances:  69%|██████▉   | 69/100 [00:12<00:06,  5.01it/s]
# Generating positive instances:  70%|███████   | 70/100 [00:12<00:05,  5.04it/s]
# Generating positive instances:  71%|███████   | 71/100 [00:12<00:06,  4.73it/s]
# Generating positive instances:  72%|███████▏  | 72/100 [00:12<00:05,  4.87it/s]
# Generating positive instances:  73%|███████▎  | 73/100 [00:12<00:05,  5.16it/s]
# Generating positive instances:  74%|███████▍  | 74/100 [00:13<00:05,  5.08it/s]
# Generating positive instances:  75%|███████▌  | 75/100 [00:13<00:05,  4.52it/s]
# Generating positive instances:  76%|███████▌  | 76/100 [00:13<00:05,  4.78it/s]
# Generating positive instances:  77%|███████▋  | 77/100 [00:13<00:05,  4.60it/s]
# Generating positive instances:  78%|███████▊  | 78/100 [00:13<00:04,  4.72it/s]
# Generating positive instances:  79%|███████▉  | 79/100 [00:14<00:04,  5.00it/s]
# Generating positive instances:  80%|████████  | 80/100 [00:14<00:04,  4.96it/s]
# Generating positive instances:  81%|████████  | 81/100 [00:14<00:03,  5.03it/s]
# Generating positive instances:  82%|████████▏ | 82/100 [00:14<00:03,  5.17it/s]
# Generating positive instances:  83%|████████▎ | 83/100 [00:14<00:03,  4.99it/s]
# Generating positive instances:  84%|████████▍ | 84/100 [00:15<00:03,  5.27it/s]
# Generating positive instances:  85%|████████▌ | 85/100 [00:15<00:02,  5.23it/s]
# Generating positive instances:  86%|████████▌ | 86/100 [00:15<00:02,  5.16it/s]
# Generating positive instances:  87%|████████▋ | 87/100 [00:15<00:02,  4.73it/s]
# Generating positive instances:  88%|████████▊ | 88/100 [00:15<00:02,  5.09it/s]
# Generating positive instances:  89%|████████▉ | 89/100 [00:16<00:02,  4.91it/s]
# Generating positive instances:  90%|█████████ | 90/100 [00:16<00:01,  5.17it/s]
# Generating positive instances:  91%|█████████ | 91/100 [00:16<00:01,  5.45it/s]
# Generating positive instances:  92%|█████████▏| 92/100 [00:16<00:01,  5.95it/s]
# Generating positive instances:  93%|█████████▎| 93/100 [00:16<00:01,  5.62it/s]
# Generating positive instances:  94%|█████████▍| 94/100 [00:16<00:00,  6.45it/s]
# Generating positive instances:  95%|█████████▌| 95/100 [00:16<00:00,  6.89it/s]
# Generating positive instances:  96%|█████████▌| 96/100 [00:17<00:00,  7.34it/s]
# Generating positive instances:  97%|█████████▋| 97/100 [00:17<00:00,  7.57it/s]
# Generating positive instances:  98%|█████████▊| 98/100 [00:17<00:00,  7.58it/s]
# Generating positive instances:  99%|█████████▉| 99/100 [00:17<00:00,  7.98it/s]
# Generating positive instances: 100%|██████████| 100/100 [00:17<00:00,  5.70it/s]
#
# Generating negative instances:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating negative instances:   1%|          | 1/100 [00:09<15:23,  9.33s/it]
# Generating negative instances:   2%|▏         | 2/100 [00:20<17:21, 10.63s/it]
# Generating negative instances:   3%|▎         | 3/100 [00:31<17:09, 10.61s/it]
# Generating negative instances:   4%|▍         | 4/100 [00:41<16:48, 10.51s/it]
# Generating negative instances:   5%|▌         | 5/100 [00:53<17:21, 10.96s/it]
# Generating negative instances:   6%|▌         | 6/100 [01:03<16:24, 10.47s/it]
# Generating negative instances:   7%|▋         | 7/100 [01:14<16:52, 10.89s/it]
# Generating negative instances:   8%|▊         | 8/100 [01:24<16:17, 10.63s/it]
# Generating negative instances:   9%|▉         | 9/100 [01:35<16:13, 10.69s/it]
# Generating negative instances:  10%|█         | 10/100 [01:47<16:20, 10.89s/it]
# Generating negative instances:  11%|█         | 11/100 [01:56<15:32, 10.48s/it]
# Generating negative instances:  12%|█▏        | 12/100 [02:08<15:56, 10.87s/it]
# Generating negative instances:  13%|█▎        | 13/100 [02:17<15:08, 10.44s/it]
# Generating negative instances:  14%|█▍        | 14/100 [02:29<15:23, 10.74s/it]
# Generating negative instances:  15%|█▌        | 15/100 [02:39<15:10, 10.71s/it]
# Generating negative instances:  16%|█▌        | 16/100 [02:50<14:58, 10.70s/it]
# Generating negative instances:  17%|█▋        | 17/100 [03:02<15:14, 11.01s/it]
# Generating negative instances:  18%|█▊        | 18/100 [03:11<14:14, 10.42s/it]
# Generating negative instances:  19%|█▉        | 19/100 [03:23<14:36, 10.82s/it]
# Generating negative instances:  20%|██        | 20/100 [03:33<14:10, 10.63s/it]
# Generating negative instances:  21%|██        | 21/100 [03:44<14:01, 10.65s/it]
# Generating negative instances:  22%|██▏       | 22/100 [03:55<14:06, 10.85s/it]
# Generating negative instances:  23%|██▎       | 23/100 [04:04<13:24, 10.45s/it]
# Generating negative instances:  24%|██▍       | 24/100 [04:17<14:13, 11.23s/it]
# Generating negative instances:  25%|██▌       | 25/100 [04:28<13:54, 11.13s/it]
# Generating negative instances:  26%|██▌       | 26/100 [04:40<13:57, 11.32s/it]
# Generating negative instances:  27%|██▋       | 27/100 [04:49<12:56, 10.63s/it]
# Generating negative instances:  28%|██▊       | 28/100 [05:01<13:09, 10.97s/it]
# Generating negative instances:  29%|██▉       | 29/100 [05:11<12:40, 10.71s/it]
# Generating negative instances:  30%|███       | 30/100 [05:22<12:30, 10.72s/it]
# Generating negative instances:  31%|███       | 31/100 [05:33<12:33, 10.92s/it]
# Generating negative instances:  32%|███▏      | 32/100 [05:43<11:55, 10.52s/it]
# Generating negative instances:  33%|███▎      | 33/100 [05:55<12:11, 10.92s/it]
# Generating negative instances:  34%|███▍      | 34/100 [06:04<11:33, 10.51s/it]
# Generating negative instances:  35%|███▌      | 35/100 [06:15<11:39, 10.76s/it]
# Generating negative instances:  36%|███▌      | 36/100 [06:26<11:27, 10.75s/it]
# Generating negative instances:  37%|███▋      | 37/100 [06:36<11:07, 10.60s/it]
# Generating negative instances:  38%|███▊      | 38/100 [06:48<11:19, 10.97s/it]
# Generating negative instances:  39%|███▉      | 39/100 [06:57<10:37, 10.45s/it]
# Generating negative instances:  40%|████      | 40/100 [07:09<10:49, 10.83s/it]
# Generating negative instances:  41%|████      | 41/100 [07:20<10:37, 10.81s/it]
# Generating negative instances:  42%|████▏     | 42/100 [07:31<10:24, 10.77s/it]
# Generating negative instances:  43%|████▎     | 43/100 [07:42<10:28, 11.03s/it]
# Generating negative instances:  44%|████▍     | 44/100 [07:52<09:49, 10.52s/it]
# Generating negative instances:  45%|████▌     | 45/100 [08:03<09:59, 10.91s/it]
# Generating negative instances:  46%|████▌     | 46/100 [08:13<09:33, 10.61s/it]
# Generating negative instances:  47%|████▋     | 47/100 [08:24<09:31, 10.78s/it]
# Generating negative instances:  48%|████▊     | 48/100 [08:36<09:31, 10.98s/it]
# Generating negative instances:  49%|████▉     | 49/100 [08:49<09:46, 11.49s/it]
# Generating negative instances:  50%|█████     | 50/100 [09:00<09:39, 11.58s/it]
# Generating negative instances:  51%|█████     | 51/100 [09:10<08:57, 10.98s/it]
# Generating negative instances:  52%|█████▏    | 52/100 [09:21<08:53, 11.11s/it]
# Generating negative instances:  53%|█████▎    | 53/100 [09:32<08:39, 11.05s/it]
# Generating negative instances:  54%|█████▍    | 54/100 [09:42<08:15, 10.77s/it]
# Generating negative instances:  55%|█████▌    | 55/100 [09:54<08:19, 11.10s/it]
# Generating negative instances:  56%|█████▌    | 56/100 [10:03<07:43, 10.53s/it]
# Generating negative instances:  57%|█████▋    | 57/100 [10:15<07:50, 10.94s/it]
# Generating negative instances:  58%|█████▊    | 58/100 [10:26<07:34, 10.81s/it]
# Generating negative instances:  59%|█████▉    | 59/100 [10:36<07:20, 10.74s/it]
# Generating negative instances:  60%|██████    | 60/100 [10:48<07:21, 11.05s/it]
# Generating negative instances:  61%|██████    | 61/100 [10:57<06:49, 10.51s/it]
# Generating negative instances:  62%|██████▏   | 62/100 [11:09<06:54, 10.90s/it]
# Generating negative instances:  63%|██████▎   | 63/100 [11:19<06:32, 10.61s/it]
# Generating negative instances:  64%|██████▍   | 64/100 [11:30<06:26, 10.74s/it]
# Generating negative instances:  65%|██████▌   | 65/100 [11:41<06:20, 10.87s/it]
# Generating negative instances:  66%|██████▌   | 66/100 [11:51<05:59, 10.57s/it]
# Generating negative instances:  67%|██████▋   | 67/100 [12:03<06:01, 10.94s/it]
# Generating negative instances:  68%|██████▊   | 68/100 [12:12<05:34, 10.44s/it]
# Generating negative instances:  69%|██████▉   | 69/100 [12:24<05:34, 10.80s/it]
# Generating negative instances:  70%|███████   | 70/100 [12:35<05:22, 10.76s/it]
# Generating negative instances:  71%|███████   | 71/100 [12:45<05:09, 10.66s/it]
# Generating negative instances:  72%|███████▏  | 72/100 [12:57<05:08, 11.03s/it]
# Generating negative instances:  73%|███████▎  | 73/100 [13:06<04:43, 10.48s/it]
# Generating negative instances:  74%|███████▍  | 74/100 [13:20<04:58, 11.46s/it]
# Generating negative instances:  75%|███████▌  | 75/100 [13:30<04:37, 11.09s/it]
# Generating negative instances:  76%|███████▌  | 76/100 [13:41<04:26, 11.11s/it]
# Generating negative instances:  77%|███████▋  | 77/100 [13:52<04:10, 10.87s/it]
# Generating negative instances:  78%|███████▊  | 78/100 [14:02<03:57, 10.81s/it]
# Generating negative instances:  79%|███████▉  | 79/100 [14:14<03:51, 11.04s/it]
# Generating negative instances:  80%|████████  | 80/100 [14:23<03:30, 10.55s/it]
# Generating negative instances:  81%|████████  | 81/100 [14:35<03:27, 10.93s/it]
# Generating negative instances:  82%|████████▏ | 82/100 [14:45<03:10, 10.56s/it]
# Generating negative instances:  83%|████████▎ | 83/100 [14:56<03:02, 10.76s/it]
# Generating negative instances:  84%|████████▍ | 84/100 [15:07<02:53, 10.85s/it]
# Generating negative instances:  85%|████████▌ | 85/100 [15:17<02:39, 10.60s/it]
# Generating negative instances:  86%|████████▌ | 86/100 [15:29<02:33, 10.97s/it]
# Generating negative instances:  87%|████████▋ | 87/100 [15:38<02:15, 10.43s/it]
# Generating negative instances:  88%|████████▊ | 88/100 [15:50<02:10, 10.84s/it]
# Generating negative instances:  89%|████████▉ | 89/100 [16:00<01:57, 10.72s/it]
# Generating negative instances:  90%|█████████ | 90/100 [16:11<01:46, 10.66s/it]
# Generating negative instances:  91%|█████████ | 91/100 [16:23<01:39, 11.01s/it]
# Generating negative instances:  92%|█████████▏| 92/100 [16:32<01:23, 10.47s/it]
# Generating negative instances:  93%|█████████▎| 93/100 [16:44<01:16, 10.86s/it]
# Generating negative instances:  94%|█████████▍| 94/100 [16:54<01:03, 10.62s/it]
# Generating negative instances:  95%|█████████▌| 95/100 [17:05<00:53, 10.74s/it]
# Generating negative instances:  96%|█████████▌| 96/100 [17:16<00:43, 10.90s/it]
# Generating negative instances:  97%|█████████▋| 97/100 [17:26<00:31, 10.56s/it]
# Generating negative instances:  98%|█████████▊| 98/100 [17:38<00:21, 10.96s/it]
# Generating negative instances:  99%|█████████▉| 99/100 [17:51<00:11, 11.74s/it]
# Generating negative instances: 100%|██████████| 100/100 [18:02<00:00, 10.82s/it]
# Training epoch 1/2:   0%|          | 0/100 [18:34<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-994b440b3da2> in <cell line: 5>()
#      14
#      15         # Forward pass
# ---> 16         loss = model(ecgs, diagnoses)
#      17
#      18         # Backward pass and optimize
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-31-b9bd2d6b58a1> in forward(self, ecgs, diagnoses)
#      13         # Compute loss based on whether the pair of embeddings is a positive or negative instance
#      14         loss = sum(F.cosine_similarity(ecgs_embeddings[i], diagnoses_embeddings[i]) for i in range(len(ecgs)) if (ecgs_embeddings[i], diagnoses_embeddings[i]) in positive_instances) \
# ---> 15              - sum(F.cosine_similarity(ecgs_embeddings[i], diagnoses_embeddings[i]) for i in range(len(ecgs)) if (ecgs_embeddings[i], diagnoses_embeddings[i]) in negative_instances)
#      16         return loss
#
# <ipython-input-31-b9bd2d6b58a1> in <genexpr>(.0)
#      13         # Compute loss based on whether the pair of embeddings is a positive or negative instance
#      14         loss = sum(F.cosine_similarity(ecgs_embeddings[i], diagnoses_embeddings[i]) for i in range(len(ecgs)) if (ecgs_embeddings[i], diagnoses_embeddings[i]) in positive_instances) \
# ---> 15              - sum(F.cosine_similarity(ecgs_embeddings[i], diagnoses_embeddings[i]) for i in range(len(ecgs)) if (ecgs_embeddings[i], diagnoses_embeddings[i]) in negative_instances)
#      16         return loss
#
# RuntimeError: The size of tensor a (768) must match the size of tensor b (126) at non-singleton dimension 1

# %% [markdown]
# ```
# class CLIPModel(nn.Module):
# def
# def __init__(self, ):
# Konstantin Egorov8:28 AM
# class CLIPModule(nn.Module):
# 	def __init__(self, ):
# 		self.ecg_encoder = ECGEncoder()
# 		self.text_encoder = TextEncoder()
# 		self.triplet_loss = TripletLoss()
#
# 	def forward(self, ecgs, diagnoses):
# 		ecgs_embeddings = self.ecg_encoder(ecgs)
# 		diagnoses_embeddings = self.text_encoder(diagnoses)
# 		loss – self.triplet_loss(ecgs_embeddings, diagnoses_embeddings)
# ```
